# %% [markdown]
# # **Business Understanding:**
#
# Analyze  the Calls made in the company and try and finc out areas of improvement
#
# **Data:**
#
# [Data Source](https://www.kaggle.com/datasets/akash1vishwakarma/call-center-dataset)

# %% [markdown]
# #### **Load Libraries**

# %%
import matplotlib.pyplot as plt 
import pandas as pd 
import numpy as np 
import seaborn as sns 
from scipy import stats

# %% [markdown]
# #### **Load Data**

# %%
df = pd.read_excel('data/01 Call-Center-Dataset.xlsx')

# %% [markdown]
# # **Data Understanding:**
# - glimpse of the data(head, tail)
# - shape(dimensions)
# - columns
# - information
# - data type
# - duplicates
# - outliers
# - null values
# - descriptive stats (quantitative and qualitative)

# %% [markdown]
# #### **Glimpse of the data:**

# %%
df.head()
# Out:
#   Call Id    Agent        Date      Time              Topic Answered (Y/N)  \
# 0  ID0001    Diane  2021-01-01  09:12:58   Contract related              Y
# 1  ID0002    Becky  2021-01-01  09:12:58  Technical Support              Y
# 2  ID0003  Stewart  2021-01-01  09:47:31   Contract related              Y
# 3  ID0004     Greg  2021-01-01  09:47:31   Contract related              Y
# 4  ID0005    Becky  2021-01-01  10:00:29    Payment related              Y
#
#   Resolved  Speed of answer in seconds AvgTalkDuration  Satisfaction rating
# 0        Y                       109.0        00:02:23                  3.0
# 1        N                        70.0        00:04:02                  3.0
# 2        Y                        10.0        00:02:11                  3.0
# 3        Y                        53.0        00:00:37                  2.0
# 4        Y                        95.0        00:01:00                  3.0

# %%
df.tail()
# Out:
#      Call Id  Agent        Date      Time             Topic Answered (Y/N)  \
# 4995  ID4996    Jim  2021-03-31  16:37:55   Payment related              Y
# 4996  ID4997  Diane  2021-03-31  16:45:07   Payment related              Y
# 4997  ID4998  Diane  2021-03-31  16:53:46   Payment related              Y
# 4998  ID4999    Jim  2021-03-31  17:02:24         Streaming              Y
# 4999  ID5000  Diane  2021-03-31  17:39:50  Contract related              N
#
#      Resolved  Speed of answer in seconds AvgTalkDuration  Satisfaction rating
# 4995        Y                        22.0        00:05:40                  1.0
# 4996        Y                       100.0        00:03:16                  3.0
# 4997        Y                        84.0        00:01:49                  4.0
# 4998        Y                        98.0        00:00:58                  5.0
# 4999        N                         NaN             NaN                  NaN

# %% [markdown]
# #### **Dimensions, columns & datatypes**

# %%
rows, columns = df.shape
output = f"Records: {rows} and Features: {columns}"
print(output)
# Out:
# Records: 5000 and Features: 10

# %%
df.columns
# Out:
# Index(['Call Id', 'Agent', 'Date', 'Time', 'Topic', 'Answered (Y/N)',
#        'Resolved', 'Speed of answer in seconds', 'AvgTalkDuration',
#        'Satisfaction rating'],
#       dtype='str')

# %%
df.dtypes
# Out:
# Call Id                           str
# Agent                             str
# Date                              str
# Time                           object
# Topic                             str
# Answered (Y/N)                    str
# Resolved                          str
# Speed of answer in seconds    float64
# AvgTalkDuration                object
# Satisfaction rating           float64
# dtype: object

# %% [markdown]
# #### **Info, duplicates, null values**

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 10 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Call Id                     5000 non-null   str
#  1   Agent                       5000 non-null   str
#  2   Date                        5000 non-null   str
#  3   Time                        5000 non-null   object
#  4   Topic                       5000 non-null   str
#  5   Answered (Y/N)              5000 non-null   str
#  6   Resolved                    5000 non-null   str
#  7   Speed of answer in seconds  4054 non-null   float64
#  8   AvgTalkDuration             4054 non-null   object
#  9   Satisfaction rating         4054 non-null   float64
# dtypes: float64(2), object(2), str(6)
# memory usage: 390.8+ KB

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.isna().sum()
# Out:
# Call Id                         0
# Agent                           0
# Date                            0
# Time                            0
# Topic                           0
# Answered (Y/N)                  0
# Resolved                        0
# Speed of answer in seconds    946
# AvgTalkDuration               946
# Satisfaction rating           946
# dtype: int64

# %%
df.isnull().sum() * 100 / len(df)
# Out:
# Call Id                        0.00
# Agent                          0.00
# Date                           0.00
# Time                           0.00
# Topic                          0.00
# Answered (Y/N)                 0.00
# Resolved                       0.00
# Speed of answer in seconds    18.92
# AvgTalkDuration               18.92
# Satisfaction rating           18.92
# dtype: float64

# %%
df = df.dropna(axis=0)

# %%
df.isnull().sum() * 100 / len(df)
# Out:
# Call Id                       0.0
# Agent                         0.0
# Date                          0.0
# Time                          0.0
# Topic                         0.0
# Answered (Y/N)                0.0
# Resolved                      0.0
# Speed of answer in seconds    0.0
# AvgTalkDuration               0.0
# Satisfaction rating           0.0
# dtype: float64

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# Index: 4054 entries, 0 to 4998
# Data columns (total 10 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Call Id                     4054 non-null   str
#  1   Agent                       4054 non-null   str
#  2   Date                        4054 non-null   str
#  3   Time                        4054 non-null   object
#  4   Topic                       4054 non-null   str
#  5   Answered (Y/N)              4054 non-null   str
#  6   Resolved                    4054 non-null   str
#  7   Speed of answer in seconds  4054 non-null   float64
#  8   AvgTalkDuration             4054 non-null   object
#  9   Satisfaction rating         4054 non-null   float64
# dtypes: float64(2), object(2), str(6)
# memory usage: 348.4+ KB

# %% [markdown]
# #### **Descriptive Stats(quantitative an dqualitative)**

# %%
# TODO: Dig deeper into analysis(using visuals)

# %%
df.describe()
# Out:
#        Speed of answer in seconds  Satisfaction rating
# count                 4054.000000          4054.000000
# mean                    67.520720             3.403552
# std                     33.592872             1.212220
# min                     10.000000             1.000000
# 25%                     39.000000             3.000000
# 50%                     68.000000             3.000000
# 75%                     97.000000             4.000000
# max                    125.000000             5.000000

# %%
df.describe(include='object') # qualitative data
# Out:
# /tmp/ipykernel_6754/3942173830.py:1: Pandas4Warning: For backward compatibility, 'str' dtypes are included by select_dtypes when 'object' dtype is specified. This behavior is deprecated and will be removed in a future version. Explicitly pass 'str' to `include` to select them, or to `exclude` to remove them and silence this warning.
# See https://pandas.pydata.org/docs/user_guide/migration-3-strings.html#string-migration-select-dtypes for details on how to write code that works with pandas 2 and 3.
#   df.describe(include='object') # qualitative data
#        Call Id Agent        Date      Time      Topic Answered (Y/N) Resolved  \
# count     4054  4054        4054      4054       4054           4054     4054
# unique    4054     8          90       375          5              1        2
# top     ID0001   Jim  2021-01-11  11:55:41  Streaming              Y        Y
# freq         1   536          68        27        847           4054     3646
#
#        AvgTalkDuration
# ...

# %%
df.head(20)
# Out:
#    Call Id    Agent        Date      Time              Topic Answered (Y/N)  \
# 0   ID0001    Diane  2021-01-01  09:12:58   Contract related              Y
# 1   ID0002    Becky  2021-01-01  09:12:58  Technical Support              Y
# 2   ID0003  Stewart  2021-01-01  09:47:31   Contract related              Y
# 3   ID0004     Greg  2021-01-01  09:47:31   Contract related              Y
# 4   ID0005    Becky  2021-01-01  10:00:29    Payment related              Y
# 6   ID0007    Diane  2021-01-01  10:22:05    Payment related              Y
# 7   ID0008    Diane  2021-01-01  10:22:05    Payment related              Y
# 8   ID0009     Greg  2021-01-01  11:13:55      Admin Support              Y
# 9   ID0010      Jim  2021-01-01  11:13:55          Streaming              Y
# 11  ID0012     Greg  2021-01-01  11:15:22    Payment related              Y
# 12  ID0013      Joe  2021-01-01  11:52:48    Payment related              Y
# ...

# %%
(3646/4054)*100
# Out:
# 89.93586581154416

# %%
(536/4054)*100
# Out:
# 13.22150962012827

# %%
# pie chart
def plotPieChart(labels, data):
    fig, ax = plt.subplots()
    ax.pie(data, labels=labels)

# %%
call_center_agent_labels  = df['Agent'].unique()
call_center_agent_labels
# Out:
# <StringArray>
# ['Diane', 'Becky', 'Stewart', 'Greg', 'Jim', 'Joe', 'Martha', 'Dan']
# Length: 8, dtype: str

# %%
agents_df = df['Agent'].value_counts()

# %%
agents_df = pd.DataFrame(agents_df).reset_index()
agents_df.columns = ['agent','count']

# %%
df['Agent'].value_counts()
# Out:
# Agent
# Jim        536
# Dan        523
# Becky      517
# Martha     514
# Greg       502
# Diane      501
# Joe        484
# Stewart    477
# Name: count, dtype: int64

# %%
agents_df
# Out:
#      agent  count
# 0      Jim    536
# 1      Dan    523
# 2    Becky    517
# 3   Martha    514
# 4     Greg    502
# 5    Diane    501
# 6      Joe    484
# 7  Stewart    477

# %%
plotPieChart(agents_df['agent'],agents_df['count'] )

# %%
topics_df = df['Topic'].value_counts()
topics_df = pd.DataFrame(topics_df).reset_index()
topics_df.columns = ['Topic','count']
plotPieChart(topics_df['Topic'],topics_df['count'] )

# %%
resolved_df = df['Resolved'].value_counts()
resolved_df = pd.DataFrame(resolved_df).reset_index()
resolved_df.columns = ['Resolved','count']
plotPieChart(resolved_df['Resolved'],resolved_df['count'] )

# %% [markdown]
# Insights:
# - we have missing values in the  Speed of answer in seconds, AvgTalkDuration and Satisfaction rating  features
# - no duplicates found
# - we had 19% of missing values in the dataset the **remedy** was to drop it as the count was small
#
# **Speed of answer in seconds:**
# - It took an average of 67.52s to answer the calls
# - The calls were spread out at approx.  33.59sec from the (arithmetic) average response time
# - The fastest reponse time was at 10sec
# - The longest wait time to respond to a call was 125sec
# - 25% of the calls took less than 39 sec of response time
# - 50% (median) of the call attendants took 68sec to answer the call
# - 75% of the calls tok less than 97sec to be answered
#
# **Agent:**
# - Jim handled approximately 13% (536 calls) of the calls
# - approximately 90% of the issues were resolved
# - we recive 100% calls answered

# %% [markdown]
# <hr>
#
# <hr>

# %% [markdown]
# # **Poisson Distribution:**
# Key focus:
#     - probability of attaining k events
#     - fixed interval
#     eg attaining 5 emails per hour
#
# param: λ
#
# Assumptions:
# => mean = variance = λ
#
# - λ is low => +ve skewness (either ad dmore data or take up a bayesian approach)
# - λ is high ( λ >30) => high variability but tends towards anormal distrbution(the distrution takes up an aproximate bell shape curve)

# %% [markdown]
# #### **Objective could be: the probablity of attaining 100 calls or more per day**
#
#    k = 100

# %%
df = pd.read_excel('data/01 Call-Center-Dataset.xlsx')
df.dtypes
# Out:
# Call Id                           str
# Agent                             str
# Date                              str
# Time                           object
# Topic                             str
# Answered (Y/N)                    str
# Resolved                          str
# Speed of answer in seconds    float64
# AvgTalkDuration                object
# Satisfaction rating           float64
# dtype: object

# %%
df['Date'].max() -  df['Date'].min()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[67], line 1
# ----> 1 df['Date'].max() -  df['Date'].min()
#
# TypeError: unsupported operand type(s) for -: 'str' and 'str'

# %%
# convert the Date t o datetime
df['Date'] = pd.to_datetime(df['Date'])
df.dtypes
# Out:
# Call Id                                  str
# Agent                                    str
# Date                          datetime64[us]
# Time                                  object
# Topic                                    str
# Answered (Y/N)                           str
# Resolved                                 str
# Speed of answer in seconds           float64
# AvgTalkDuration                       object
# Satisfaction rating                  float64
# dtype: object

# %%
df['Date'].max() -  df['Date'].min()
# Out:
# Timedelta('89 days 00:00:00')

# %%
df['Date'].unique()
# Out:
# <DatetimeArray>
# ['2021-01-01 00:00:00', '2021-01-02 00:00:00', '2021-01-03 00:00:00',
#  '2021-01-04 00:00:00', '2021-01-05 00:00:00', '2021-01-06 00:00:00',
#  '2021-01-07 00:00:00', '2021-01-08 00:00:00', '2021-01-09 00:00:00',
#  '2021-01-10 00:00:00', '2021-01-11 00:00:00', '2021-01-12 00:00:00',
#  '2021-01-13 00:00:00', '2021-01-14 00:00:00', '2021-01-15 00:00:00',
#  '2021-01-16 00:00:00', '2021-01-17 00:00:00', '2021-01-18 00:00:00',
#  '2021-01-19 00:00:00', '2021-01-20 00:00:00', '2021-01-21 00:00:00',
#  '2021-01-22 00:00:00', '2021-01-23 00:00:00', '2021-01-24 00:00:00',
#  '2021-01-25 00:00:00', '2021-01-26 00:00:00', '2021-01-27 00:00:00',
#  '2021-01-28 00:00:00', '2021-01-29 00:00:00', '2021-01-30 00:00:00',
#  '2021-01-31 00:00:00', '2021-02-01 00:00:00', '2021-02-02 00:00:00',
#  '2021-02-03 00:00:00', '2021-02-04 00:00:00', '2021-02-05 00:00:00',
#  '2021-02-06 00:00:00', '2021-02-07 00:00:00', '2021-02-08 00:00:00',
# ...

# %%
df.head(10)
# Out:
#   Call Id    Agent       Date      Time              Topic Answered (Y/N)  \
# 0  ID0001    Diane 2021-01-01  09:12:58   Contract related              Y
# 1  ID0002    Becky 2021-01-01  09:12:58  Technical Support              Y
# 2  ID0003  Stewart 2021-01-01  09:47:31   Contract related              Y
# 3  ID0004     Greg 2021-01-01  09:47:31   Contract related              Y
# 4  ID0005    Becky 2021-01-01  10:00:29    Payment related              Y
# 5  ID0006  Stewart 2021-01-01  10:00:29  Technical Support              N
# 6  ID0007    Diane 2021-01-01  10:22:05    Payment related              Y
# 7  ID0008    Diane 2021-01-01  10:22:05    Payment related              Y
# 8  ID0009     Greg 2021-01-01  11:13:55      Admin Support              Y
# 9  ID0010      Jim 2021-01-01  11:13:55          Streaming              Y
#
#   Resolved  Speed of answer in seconds AvgTalkDuration  Satisfaction rating
# 0        Y                       109.0        00:02:23                  3.0
# ...

# %%
df.shape
# Out:
# (5000, 10)

# %% [markdown]
# #### **Aggregate the Date columns to days and use the frequency of occurence pper day to indicate the number of calls answered during the day**
#
# Code explanations:
# - df['Date'].dt.date: Extracts the date part (ignoring time) from a datetime

# %%
calls_per_day = df.groupby(df['Date'].dt.date).size().reset_index()
calls_per_day.columns = ['date', 'number_of_calls']
calls_per_day
# Out:
#           date  number_of_calls
# 0   2021-01-01               58
# 1   2021-01-02               60
# 2   2021-01-03               58
# 3   2021-01-04               54
# 4   2021-01-05               56
# ..         ...              ...
# 85  2021-03-27               58
# 86  2021-03-28               38
# 87  2021-03-29               60
# 88  2021-03-30               25
# 89  2021-03-31               27
#
# [90 rows x 2 columns]

# %% [markdown]
# #### **Poisson assumptions:**
#  mean = variance = lambda

# %%
mean = calls_per_day['number_of_calls'].mean()
variance = calls_per_day['number_of_calls'].var()
print(f"Mean: {mean} || Variance: {variance}")
# Out:
# Mean: 55.55555555555556 || Variance: 102.6541822721598

# %%
calls_per_day.describe()
# Out:
#        number_of_calls
# count        90.000000
# mean         55.555556
# std          10.131840
# min          25.000000
# 25%          50.000000
# 50%          56.000000
# 75%          61.500000
# max          84.000000

# %%
calls_per_day.head(30)
# Out:
#           date  number_of_calls
# 0   2021-01-01               58
# 1   2021-01-02               60
# 2   2021-01-03               58
# 3   2021-01-04               54
# 4   2021-01-05               56
# 5   2021-01-06               58
# 6   2021-01-07               54
# 7   2021-01-08               48
# 8   2021-01-09               68
# 9   2021-01-10               64
# 10  2021-01-11               84
# 11  2021-01-12               56
# 12  2021-01-13               40
# 13  2021-01-14               58
# 14  2021-01-15               46
# 15  2021-01-16               56
# 16  2021-01-17               50
# 17  2021-01-18               62
# 18  2021-01-19               62
# 19  2021-01-20               40
# 20  2021-01-21               48
# 21  2021-01-22               50
# 22  2021-01-23               54
# 23  2021-01-24               54
# 24  2021-01-25               64
# 25  2021-01-26               60
# 26  2021-01-27               56
# 27  2021-01-28               56
# ...

# %%
calls_per_day.tail(30)
# Out:
#           date  number_of_calls
# 60  2021-03-02               62
# 61  2021-03-03               52
# 62  2021-03-04               70
# 63  2021-03-05               54
# 64  2021-03-06               62
# 65  2021-03-07               48
# 66  2021-03-08               56
# 67  2021-03-09               46
# 68  2021-03-10               46
# 69  2021-03-11               74
# 70  2021-03-12               50
# 71  2021-03-13               48
# 72  2021-03-14               50
# 73  2021-03-15               50
# 74  2021-03-16               60
# 75  2021-03-17               50
# 76  2021-03-18               48
# 77  2021-03-19               42
# 78  2021-03-20               56
# 79  2021-03-21               62
# 80  2021-03-22               54
# 81  2021-03-23               46
# 82  2021-03-24               54
# 83  2021-03-25               46
# 84  2021-03-26               54
# 85  2021-03-27               58
# 86  2021-03-28               38
# 87  2021-03-29               60
# ...

# %%
# Plot daily call volume over time
plt.figure(figsize=(14, 4))
plt.plot(calls_per_day['date'], calls_per_day['number_of_calls'], marker='o', markersize=3, linewidth=1)
plt.title('Daily Call Volume (Jan–Mar 2021)')
plt.xlabel('Date')
plt.ylabel('Calls per Day')
plt.grid(alpha=0.3)
plt.tight_layout()
plt.show()

# %%
# TODO: Check which days were best to pick calls and which days were worst to make/pick calls

# %% [markdown]
# #### **Back to our obective: probability of *getting 100 calls* or *more* per day**
#
# - **Probability Mass Functoin(PMF)**: **exactly** k=100
# - **Cumulative Density Function(CDF)**: **atmost** k values/ events k <= 100
# - **1 - Cumulative Density Function(CDF)**: **atleast** k events k >= 100  **

# %%
calls_per_day.columns
# Out:
# Index(['date', 'number_of_calls'], dtype='str')

# %%
calls_per_day['number_of_calls'].mean()
# Out:
# np.float64(55.55555555555556)

# %%
lambda_hat = calls_per_day['number_of_calls'].mean()

k  = 100

# attaining exactly 100 calls (PMF) => k=100: 
p_exact = stats.poisson.pmf(k, lambda_hat)

# attaining atmost 100 calls (CDF) => k<=100:
p_atmost = stats.poisson.cdf(k, lambda_hat) 

# attaining atleast 100 calls (CDF) => k >= 100:
p_atleast = 1 - stats.poisson.cdf(k, lambda_hat) 

print(f"Probabilty of getting exaclty {k} outcomes is {p_exact:.6f} ")
print(f"Probabilty of getting atmost {k} outcomes is {p_atmost:.6f} ")
print(f"Probabilty of getting atleast {k} outcomes is {p_atleast:.6f} ")
# Out:
# Probabilty of getting exaclty 100 outcomes is 0.000000
# Probabilty of getting atmost 100 outcomes is 1.000000
# Probabilty of getting atleast 100 outcomes is 0.000000

# %%
lambda_hat = calls_per_day['number_of_calls'].mean()

k  = 50

# attaining exactly 100 calls (PMF) => k=100: 
p_exact = stats.poisson.pmf(k, lambda_hat)

# attaining atmost 100 calls (CDF) => k<=100:
p_atmost = stats.poisson.cdf(k, lambda_hat) 

# attaining atleast 100 calls (CDF) => k >= 100:
p_atleast = 1 - stats.poisson.cdf(k, lambda_hat) 

print(f"Probabilty of getting exaclty {k} outcomes is {p_exact:.6f} ")
print(f"Probabilty of getting atmost {k} outcomes is {p_atmost:.6f} ")
print(f"Probabilty of getting atleast {k} outcomes is {p_atleast:.6f} ")
# Out:
# Probabilty of getting exaclty 50 outcomes is 0.042250
# Probabilty of getting atmost 50 outcomes is 0.252640
# Probabilty of getting atleast 50 outcomes is 0.747360

# %%
lambda_hat = calls_per_day['number_of_calls'].mean()

k  = 64

# attaining exactly 100 calls (PMF) => k=100: 
p_exact = stats.poisson.pmf(k, lambda_hat)

# attaining atmost 100 calls (CDF) => k<=100:
p_atmost = stats.poisson.cdf(k, lambda_hat) 

# attaining atleast 100 calls (CDF) => k >= 100:
p_atleast = 1 - stats.poisson.cdf(k, lambda_hat) 

print(f"Probabilty of getting exaclty {k} outcomes is {p_exact:.6f} ")
print(f"Probabilty of getting atmost {k} outcomes is {p_atmost:.6f} ")
print(f"Probabilty of getting atleast {k} outcomes is {p_atleast:.6f} ")
# Out:
# Probabilty of getting exaclty 64 outcomes is 0.027019
# Probabilty of getting atmost 64 outcomes is 0.883300
# Probabilty of getting atleast 64 outcomes is 0.116700

# %%
# Plot histogram
counts, bins, patches = plt.hist(calls_per_day['number_of_calls'], bins=5, alpha=0.7, 
                                  color='skyblue', edgecolor='black', 
                                  density=True, label='Actual data')
# Generate points for the Poisson distribution line
x = np.arange(calls_per_day['number_of_calls'].min() - 2, calls_per_day['number_of_calls'].max() + 3, 1)
poisson_values = stats.poisson.pmf(x, lambda_hat)

# Plot Poisson distribution line
plt.plot(x, poisson_values, 'ro-', linewidth=2, markersize=8, 
         label=f'Poisson distribution (λ={lambda_hat:.2f})', 
         markerfacecolor='red', markeredgecolor='darkred')

# Add vertical line for the mean
plt.axvline(lambda_hat, color='green', linestyle='--', 
            linewidth=2, label=f'Mean = {lambda_hat:.2f}')

# Customize the plot
plt.xlabel('Number of Calls per Day', fontsize=12)
plt.ylabel('Probability Density', fontsize=12)
plt.title('Distribution of Daily Call Volume', fontsize=14, fontweight='bold')
plt.legend(fontsize=10)
plt.grid(True, alpha=0.3)

# Add value labels on the histogram bars
for i, (bins, patches) in enumerate(zip(bins[:-1], patches)):
    height = patches.get_height()
    if height > 0:
        plt.text(bins + 0.5, height + 0.01, 
                 f'{calls_per_day["number_of_calls"].iloc[i]}', 
                 ha='center', fontsize=10)

# Add text box with statistics
stats_text = f'Total days: {len(calls_per_day)}\nMean (λ): {lambda_hat:.2f}\nVariance: {calls_per_day["number_of_calls"].var():.2f}'
plt.text(0.02, 0.98, stats_text, transform=plt.gca().transAxes, 
         fontsize=10, verticalalignment='top',
         bbox=dict(boxstyle='round', facecolor='wheat', alpha=0.5))

plt.tight_layout()
plt.show()

# %%
calls_per_day = calls_per_day.loc[:20]

# %%
calls_per_day['number_of_calls'].mean()
# Out:
# np.float64(56.19047619047619)

# %%
# Plot histogram
counts, bins, patches = plt.hist(calls_per_day['number_of_calls'], bins=5, alpha=0.7, 
                                  color='skyblue', edgecolor='black', 
                                  density=True, label='Actual data')
# Generate points for the Poisson distribution line
x = np.arange(calls_per_day['number_of_calls'].min() - 2, calls_per_day['number_of_calls'].max() + 3, 1)
poisson_values = stats.poisson.pmf(x, lambda_hat)

# Plot Poisson distribution line
plt.plot(x, poisson_values, 'ro-', linewidth=2, markersize=8, 
         label=f'Poisson distribution (λ={lambda_hat:.2f})', 
         markerfacecolor='red', markeredgecolor='darkred')

# Add vertical line for the mean
plt.axvline(lambda_hat, color='green', linestyle='--', 
            linewidth=2, label=f'Mean = {lambda_hat:.2f}')

# Customize the plot
plt.xlabel('Number of Calls per Day', fontsize=12)
plt.ylabel('Probability Density', fontsize=12)
plt.title('Distribution of Daily Call Volume', fontsize=14, fontweight='bold')
plt.legend(fontsize=10)
plt.grid(True, alpha=0.3)

# Add value labels on the histogram bars
for i, (bins, patches) in enumerate(zip(bins[:-1], patches)):
    height = patches.get_height()
    if height > 0:
        plt.text(bins + 0.5, height + 0.01, 
                 f'{calls_per_day["number_of_calls"].iloc[i]}', 
                 ha='center', fontsize=10)

# Add text box with statistics
stats_text = f'Total days: {len(calls_per_day)}\nMean (λ): {lambda_hat:.2f}\nVariance: {calls_per_day["number_of_calls"].var():.2f}'
plt.text(0.02, 0.98, stats_text, transform=plt.gca().transAxes, 
         fontsize=10, verticalalignment='top',
         bbox=dict(boxstyle='round', facecolor='wheat', alpha=0.5))

plt.tight_layout()
plt.show()

# %%
# Add a comparison of actual variance vs Poisson variance
plt.figure(figsize=(8, 4))
plt.bar(['Actual Variance', 'Poisson Variance'], 
        [variance, lambda_hat], 
        color=['red', 'blue'], alpha=0.7)
plt.axhline(y=lambda_hat, color='blue', linestyle='--', alpha=0.5)
plt.title('Variance Comparison: Actual vs Poisson')
plt.ylabel('Variance')
# Out:
# Text(0, 0.5, 'Variance')

# %% [markdown]
# insights:
# - The above has illustrates the level of overdispersion, recall in poisson distribution mean = variance = lambda right? Now look at this our actual variance from the data is almost twice that of poisson

# %% [markdown]
# Insights:
# - there exists a vehry high variation => the data is over dispersed ( this could imply that there existed day where call were more as opposed to other eg weekends could prob'ly have less alls as opposed to weekday or holidays hence this somehow resembles real world data)
# -  the mean and the mvariance are not equal, hence poisson could most likely be the wrong model to use
# - Fridays received lower calls answered than other days

# %% [markdown]
# Note:
#
# Considering Poisson Distributoin(unable to handle overdispersoin) does not befit the above data, we may have to try out ther distributions:
#     - negative binomial
#     - Bayesian
#
# - With Poissson(frequentist), if  λ exists, let's estimate it and we can use it with large samples, simple problems.
#
# - With Bayesian,  λ is uncertain hence let us model that uncertaininty, small smaple, incoporating prior knowledge
