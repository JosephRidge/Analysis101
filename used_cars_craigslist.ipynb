# %% [markdown]
# # **Business Understanding**
#
# **About Dataset**
# This dataset contains used car listings sourced from Craigslist (United States) that have been cleaned to remove low-value or redundant columns and to make the data more usable for analysis and predictive modeling. The cleaned data is often used for exploratory data analysis, price prediction models, and market trend studies
#
# [Source](https://www.kaggle.com/datasets/youssefkhaled117/used-car-cleaned)

# %% [markdown]
# ### **Loading libraries**

# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt

# %% [markdown]
# ### **Loading data**

# %%
used_cars_df = pd.read_csv('data/Used_Cars_Cleaned.csv')

# %% [markdown]
# # **Data Understanding**
# - head/tail of the data
# - shape
# - column
# - info
# - data types
# - missing values
# - outliers
# - duplicates
# - descriptive stats(quantitative & qualitative)
# - basic visualizations

# %% [markdown]
# #### **Get a glimpse of the data(head, tail)**

# %%
used_cars_df.head(10)
# Out:
#            id                  region  price    year manufacturer  model  \
# 0  7222695916                prescott   6000  2017.0         ford  f-150
# 1  7218891961            fayetteville  11900  2017.0         ford  f-150
# 2  7221797935            florida keys  21000  2017.0         ford  f-150
# 3  7222270760  worcester / central MA   1500  2017.0         ford  f-150
# 4  7210384030              greensboro   4900  2017.0         ford  f-150
# 5  7222379453           hudson valley   1600  2017.0         ford  f-150
# 6  7221952215           hudson valley   1000  2017.0         ford  f-150
# 7  7220195662           hudson valley  15995  2017.0         ford  f-150
# 8  7209064557         medford-ashland   5000  2017.0         ford  f-150
# 9  7219485069                    erie   3000  2017.0         ford  f-150
#
#   condition    cylinders fuel  odometer title_status transmission drive  \
# 0      good  8 cylinders  gas  102505.0        clean    automatic   4wd
# ...

# %%
used_cars_df.tail(10)
# Out:
#                 id   region  price    year   manufacturer  \
# 392002  7301592119  wyoming  22990  2020.0        hyundai
# 392003  7301591639  wyoming  17990  2018.0            kia
# 392004  7301591201  wyoming  32590  2020.0  mercedes-benz
# 392005  7301591202  wyoming  30990  2018.0  mercedes-benz
# 392006  7301591199  wyoming  33590  2018.0          lexus
# 392007  7301591192  wyoming  23590  2019.0         nissan
# 392008  7301591187  wyoming  30590  2020.0          volvo
# 392009  7301591147  wyoming  34990  2020.0       cadillac
# 392010  7301591140  wyoming  28990  2018.0          lexus
# 392011  7301591129  wyoming  30590  2019.0            bmw
#
#                                model condition    cylinders    fuel  odometer  \
# 392002            sonata se sedan 4d      good  4 cylinders     gas    3066.0
# 392003  sportage lx sport utility 4d      good  6 cylinders     gas   34239.0
# 392004                 c-class c 300      good  4 cylinders     gas   19059.0
# ...

# %% [markdown]
# #### **Shape/ dimensions & columns/ features of data**

# %%
rows, columns  = used_cars_df.shape
output = f"On craigs lists we have {rows} records/listings and {columns} features/attributes unser the used cars."
print(output)
# Out:
# On craigs lists we have 392012 records/listings and 18 features/attributes unser the used cars.

# %%
used_cars_df.columns
# Out:
# Index(['id', 'region', 'price', 'year', 'manufacturer', 'model', 'condition',
#        'cylinders', 'fuel', 'odometer', 'title_status', 'transmission',
#        'drive', 'type', 'paint_color', 'state', 'posting_date',
#        'posting_month'],
#       dtype='str')

# %% [markdown]
# #### **Data types, duplicates & info**

# %%
used_cars_df.dtypes
# Out:
# id                 int64
# region               str
# price              int64
# year             float64
# manufacturer         str
# model                str
# condition            str
# cylinders            str
# fuel                 str
# odometer         float64
# title_status         str
# transmission         str
# drive                str
# type                 str
# paint_color          str
# state                str
# posting_date         str
# posting_month      int64
# dtype: object

# %%
used_cars_df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 392012 entries, 0 to 392011
# Data columns (total 18 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   id             392012 non-null  int64
#  1   region         392012 non-null  str
#  2   price          392012 non-null  int64
#  3   year           392012 non-null  float64
#  4   manufacturer   392012 non-null  str
#  5   model          392012 non-null  str
#  6   condition      392012 non-null  str
#  7   cylinders      392012 non-null  str
#  8   fuel           392012 non-null  str
#  9   odometer       392012 non-null  float64
#  10  title_status   392012 non-null  str
#  11  transmission   392012 non-null  str
#  12  drive          392012 non-null  str
#  13  type           392012 non-null  str
#  14  paint_color    392012 non-null  str
#  15  state          392012 non-null  str
#  16  posting_date   392012 non-null  str
#  17  posting_month  392012 non-null  int64
# ...

# %%
used_cars_df.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# #### **Insight:**
# - On craigs lists we have 392012 records/listings and 18 features/attributes unser the used cars
# - No missing values and No duplicate data
# - 5 quantitative featues and 13 qualitative features

# %% [markdown]
# #### **Descriptive Stats (quantitative and qualitative)**

# %%
used_cars_df['year'] = used_cars_df['year'].astype("int64") # converting year column to an integer

# %%
used_cars_df.dtypes
# Out:
# id                 int64
# region               str
# price              int64
# year               int64
# manufacturer         str
# model                str
# condition            str
# cylinders            str
# fuel                 str
# odometer         float64
# title_status         str
# transmission         str
# drive                str
# type                 str
# paint_color          str
# state                str
# posting_date         str
# posting_month      int64
# dtype: object

# %%
used_cars_df.describe()
# Out:
#                  id          price           year      odometer  posting_month
# count  3.920120e+05  392012.000000  392012.000000  3.920120e+05  392012.000000
# mean   7.311479e+09   18790.591836    2011.070324  9.420378e+04       4.256344
# std    4.472080e+06   14677.465265       9.496469  7.243350e+04       0.436615
# min    7.207408e+09       1.000000    1900.000000  1.000000e+00       4.000000
# 25%    7.308124e+09    7195.000000    2008.000000  3.866900e+04       4.000000
# 50%    7.312618e+09   15111.000000    2013.000000  8.731550e+04       4.000000
# 75%    7.315249e+09   27590.000000    2017.000000  1.350682e+05       5.000000
# max    7.317101e+09  119999.000000    2022.000000  1.110000e+06       5.000000

# %% [markdown]
# #### **Insights:**
# Note that *id* is a primary_key hence not regarded as part of the descriptive stats
#
# **Price:**
# - the average of the prices fall around 18790.59
# - the pricing spreads away from the average by a standard deviation of 14677.46 (this is quite hight implying presence of outliers)
# - cheapeast vehicle is goiung USD 1
# - the  most expensive vehicle goes for USD 119,999
# - 25% of the costing are below USD 7,195
# - 50% of the costing fall around USD 15,111
# - 75% of the costing fall below USD 27,590
#
# **Year:**
# - Earliest posting/ listing was done in the year 1900
# - latest posting/ listing was done in the year 2022
# - majority of the sales were around 2013
# - 25% of the listsing were done below the year  2008
# - 50% of the listing we around the year  2013
# - 75% of the listing were below the year 2017
#
# **odometer:**
# -

# %%
used_cars_df.head(3)
# Out:
#            id        region  price  year manufacturer  model condition  \
# 0  7222695916      prescott   6000  2017         ford  f-150      good
# 1  7218891961  fayetteville  11900  2017         ford  f-150      good
# 2  7221797935  florida keys  21000  2017         ford  f-150      good
#
#      cylinders fuel  odometer title_status transmission drive    type  \
# 0  8 cylinders  gas  102505.0        clean    automatic   4wd  pickup
# 1  8 cylinders  gas  102505.0        clean    automatic   4wd  pickup
# 2  8 cylinders  gas  102505.0        clean    automatic   4wd  pickup
#
#   paint_color state posting_date  posting_month
# 0       white    az   2021-04-23              4
# 1       white    ar   2021-04-23              4
# 2       white    fl   2021-04-23              4

# %%
used_cars_df.describe(include='object')
# Out:
# /tmp/ipykernel_11467/1992075573.py:1: Pandas4Warning: For backward compatibility, 'str' dtypes are included by select_dtypes when 'object' dtype is specified. This behavior is deprecated and will be removed in a future version. Explicitly pass 'str' to `include` to select them, or to `exclude` to remove them and silence this warning.
# See https://pandas.pydata.org/docs/user_guide/migration-3-strings.html#string-migration-select-dtypes for details on how to write code that works with pandas 2 and 3.
#   used_cars_df.describe(include='object')
#           region manufacturer   model condition    cylinders    fuel  \
# count     392012       392012  392012    392012       392012  392012
# unique       404           42   27948         6            8       5
# top     columbus         ford   f-150      good  6 cylinders     gas
# freq        3375        80297    7793    269464       165670  331251
#
#        title_status transmission   drive    type paint_color   state  \
# ...

# %%
freq = used_cars_df['cylinders'].value_counts()
freq
# Out:
# cylinders
# 6 cylinders     165670
# 4 cylinders     118597
# 8 cylinders     100910
# other             2108
# 5 cylinders       2102
# 10 cylinders      1564
# 3 cylinders        811
# 12 cylinders       250
# Name: count, dtype: int64

# %%
labels = freq.index

# %%
fig, ax = plt.subplots()
ax.pie(freq, labels=labels)
# Out:
# ([<matplotlib.patches.Wedge at 0x7f7e0da28e10>,
# ...
#  [Text(0.2647981482357442, 1.0676525374347785, '6 cylinders'),
#   Text(-0.9835920958718571, -0.4924901917179748, '4 cylinders'),
#   Text(0.6679352641967542, -0.8739922670381084, '8 cylinders'),
#   Text(1.0952813146159108, -0.10177839580796234, 'other'),
#   Text(1.098091269936413, -0.06477316488667254, '5 cylinders'),
#   Text(1.0995201176785974, -0.032488626010398446, '10 cylinders'),
#   Text(1.0999392884791734, -0.011556887986378231, '3 cylinders'),
#   Text(1.0999977923052555, -0.0022038429081618974, '12 cylinders')])

# %%
freq = used_cars_df['transmission'].value_counts()
freq 

fig, ax = plt.subplots()
ax.pie(freq, labels=freq.index)
# Out:
# ([<matplotlib.patches.Wedge at 0x7f7e103ab150>,
# ...
#  [Text(-0.8549989376000152, 0.6920815101581934, 'automatic'),
#   Text(0.7097186865255937, -0.840416198080681, 'other'),
#   Text(1.0804047767098308, -0.20670152022319696, 'manual')])

# %%
freq = used_cars_df['fuel'].value_counts()
freq 

fig, ax = plt.subplots()
ax.pie(freq, labels=freq.index)
# Out:
# ([<matplotlib.patches.Wedge at 0x7f7e103ad790>,
# ...
#  [Text(-0.9721456948560507, 0.5147161819613276, 'gas'),
#   Text(0.8055243688431655, -0.7490864377358729, 'other'),
#   Text(1.0460562910977222, -0.3402443766690016, 'diesel'),
#   Text(1.0976556998501044, -0.07177718709017519, 'hybrid'),
#   Text(1.099907067282086, -0.014298368540528903, 'electric')])

# %%
freq = used_cars_df['drive'].value_counts()
freq 

fig, ax = plt.subplots()
ax.pie(freq, labels=freq.index)
# Out:
# ([<matplotlib.patches.Wedge at 0x7f7e0c781350>,
# ...
#  [Text(0.0913809238768741, 1.0961977589611325, '4wd'),
#   Text(-0.679419849314192, -0.8650946008142004, 'fwd'),
#   Text(0.9185462852660993, -0.6052046941521932, 'rwd')])
