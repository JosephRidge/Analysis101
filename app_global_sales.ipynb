# %% [markdown]
# # **Business Understanding**
#
# #### **Apple Global Product Sales Dataset**
#
# 11,500 synthetic sales transactions for iPhone, iPad, Mac, Apple Watch, AirPods, and Accessories across 47 countries, 514+ cities, sorted by Country → City → Date (2022 – 2024).
#
# This dataset simulates a realistic global sales ledger for Apple Inc. products.It covers city-level transactions across multiple continents, currencies, sales channels,and customer demographics — ideal for retail analytics, market segmentation, price analysis, time-series forecasting, and geographic visualisation.
#
# source: [Data set source](https://www.kaggle.com/datasets/ashyou09/apple-global-product-sales-dataset)

# %% [markdown]
# ## **Data Understanding**
#
# - head and tail (printing out the first 5 or few entries and the last entries)
# - shape (dimensions)
# - columns
# - datatypes
# - info
# - describe numerical (descriptive)
# - describe categroical

# %% [markdown]
# #### Load libraries

# %%
import pandas as pd
import matplotlib.pyplot  as plt
import numpy as np
pd.set_option('display.max_columns', None)  # Show all columns

# %% [markdown]
# #### Load data

# %%
apple_df = pd.read_csv("data/apple_global_sales_dataset.csv")

# %% [markdown]
# #### Get a glimpse of the data

# %%
apple_df.head(10)
# Out:
#          sale_id   sale_date  year quarter    month    country         region  \
# 0  APPL-00000001  2022-01-03  2022      Q1  January  Argentina  South America
# 1  APPL-00000002  2022-01-04  2022      Q1  January  Argentina  South America
# 2  APPL-00000003  2022-05-18  2022      Q2      May  Argentina  South America
# 3  APPL-00000004  2022-05-23  2022      Q2      May  Argentina  South America
# 4  APPL-00000005  2022-07-13  2022      Q3     July  Argentina  South America
# 5  APPL-00000006  2022-07-31  2022      Q3     July  Argentina  South America
# 6  APPL-00000007  2022-08-01  2022      Q3   August  Argentina  South America
# 7  APPL-00000008  2022-08-04  2022      Q3   August  Argentina  South America
# 8  APPL-00000009  2023-01-14  2023      Q1  January  Argentina  South America
# 9  APPL-00000010  2023-01-26  2023      Q1  January  Argentina  South America
#
#            city              product_name     category   storage      color  \
# 0  Buenos Aires         AirPods (3rd Gen)      AirPods       NaN  Starlight
# 1  Buenos Aires  USB-C Woven Charge Cable  Accessories       NaN      Black
# 2  Buenos Aires      Apple Watch Series 8  Apple Watch       NaN   Titanium
# 3  Buenos Aires  MacBook Pro 14-inch (M3)          Mac  1 TB SSD  Starlight
# 4  Buenos Aires       Apple Watch Ultra 2  Apple Watch       NaN   Midnight
# 5  Buenos Aires            Magic Keyboard  Accessories       NaN     Silver
# 6  Buenos Aires  MacBook Pro 14-inch (M3)          Mac  1 TB SSD  Starlight
# 7  Buenos Aires         iPhone 15 Pro Max       iPhone     64 GB      Black
# 8  Buenos Aires     Apple TV 4K (3rd Gen)  Accessories       NaN      White
# 9  Buenos Aires       iPad Mini (6th Gen)         iPad    128 GB  Starlight
#
#    unit_price_usd  discount_pct  units_sold  discounted_price_usd  \
# 0          159.27             7           1                148.12
# 1           29.99            15           5                 25.49
# 2          293.92             0           4                293.92
# 3         1932.77             0           2               1932.77
# 4          755.44             5           3                717.67
# 5          103.02             0           3                103.02
# 6         2003.70             3           1               1943.59
# 7         1228.96            15           8               1044.62
# 8          122.99             0           8                122.99
# 9          520.05             0           1                520.05
#
#    revenue_usd currency  fx_rate_to_usd  revenue_local_currency  \
# 0       148.12      ARS           907.0               134344.84
# 1       127.45      ARS           907.0               115597.15
# 2      1175.68      ARS           907.0              1066341.76
# 3      3865.54      ARS           907.0              3506044.78
# 4      2153.01      ARS           907.0              1952780.07
# 5       309.06      ARS           907.0               280317.42
# 6      1943.59      ARS           907.0              1762836.13
# 7      8356.96      ARS           907.0              7579762.72
# 8       983.92      ARS           907.0               892415.44
# 9       520.05      ARS           907.0               471685.35
#
#           sales_channel payment_method customer_segment customer_age_group  \
# 0  Third-Party Retailer           Cash       Government              45–54
# 1   Authorized Reseller     Debit Card         Business              45–54
# 2       Corporate / B2B    Credit Card       Individual              18–24
# 3         Carrier Store    Credit Card        Education              45–54
# 4           Apple Store    Net Banking        Education              18–24
# 5           Apple Store           Cash        Education                55+
# 6           Apple Store      Gift Card       Government              35–44
# 7         Carrier Store      Gift Card        Education              25–34
# 8   Authorized Reseller      Gift Card       Government              18–24
# 9  Third-Party Retailer      Apple Pay         Business              25–34
#
#   previous_device_os  customer_rating return_status
# 0                NaN              4.1          Kept
# 1                NaN              4.8          Kept
# 2                NaN              4.3          Kept
# 3                NaN              NaN          Kept
# 4                NaN              NaN          Kept
# 5                NaN              4.9          Kept
# 6                NaN              3.6          Kept
# 7             iOS 16              4.7          Kept
# 8                NaN              4.7          Kept
# 9                NaN              3.6          Kept

# %%
apple_df.tail(10)
# Out:
#              sale_id   sale_date  year quarter     month  country region  \
# 11490  APPL-00011491  2023-11-24  2023      Q4  November  Vietnam   Asia
# 11491  APPL-00011492  2023-11-24  2023      Q4  November  Vietnam   Asia
# 11492  APPL-00011493  2023-12-19  2023      Q4  December  Vietnam   Asia
# 11493  APPL-00011494  2023-12-29  2023      Q4  December  Vietnam   Asia
# 11494  APPL-00011495  2024-01-07  2024      Q1   January  Vietnam   Asia
# 11495  APPL-00011496  2024-02-08  2024      Q1  February  Vietnam   Asia
# 11496  APPL-00011497  2024-02-15  2024      Q1  February  Vietnam   Asia
# 11497  APPL-00011498  2024-08-28  2024      Q3    August  Vietnam   Asia
# 11498  APPL-00011499  2024-08-31  2024      Q3    August  Vietnam   Asia
# 11499  APPL-00011500  2024-10-10  2024      Q4   October  Vietnam   Asia
#
#             city                  product_name     category     storage  \
# 11490  Nha Trang                Magic Trackpad  Accessories         NaN
# 11491  Nha Trang                 iPhone 14 Pro       iPhone       64 GB
# 11492  Nha Trang                   Magic Mouse  Accessories         NaN
# 11493  Nha Trang  MacBook Pro 16-inch (M3 Pro)          Mac  256 GB SSD
# 11494  Nha Trang  MacBook Pro 16-inch (M3 Pro)          Mac    2 TB SSD
# 11495  Nha Trang          Apple Watch Series 9  Apple Watch         NaN
# 11496  Nha Trang            Mac Pro (M2 Ultra)          Mac  256 GB SSD
# 11497  Nha Trang                     iPhone 15       iPhone      128 GB
# 11498  Nha Trang           iPhone SE (3rd Gen)       iPhone      512 GB
# 11499  Nha Trang             iPhone 15 Pro Max       iPhone      512 GB
#
#              color  unit_price_usd  discount_pct  units_sold  \
# 11490       Silver          138.29             0           5
# 11491       Silver          832.10            10           2
# 11492        Black           82.20             3           2
# 11493    Starlight         2666.18             0           1
# 11494       Silver         2425.12             0           2
# 11495      Natural          420.53             5           2
# 11496     Midnight         7302.60             7           1
# 11497  Deep Purple          759.97             7           5
# 11498        Black          438.99             0           1
# 11499       Silver         1271.57             7           1
#
#        discounted_price_usd  revenue_usd currency  fx_rate_to_usd  \
# 11490                138.29       691.45      VND         24500.0
# 11491                748.89      1497.78      VND         24500.0
# 11492                 79.73       159.46      VND         24500.0
# 11493               2666.18      2666.18      VND         24500.0
# 11494               2425.12      4850.24      VND         24500.0
# 11495                399.50       799.00      VND         24500.0
# 11496               6791.42      6791.42      VND         24500.0
# 11497                706.77      3533.85      VND         24500.0
# 11498                438.99       438.99      VND         24500.0
# 11499               1182.56      1182.56      VND         24500.0
#
#        revenue_local_currency         sales_channel     payment_method  \
# 11490              16940525.0         Carrier Store         Debit Card
# 11491              36695610.0       Corporate / B2B          Gift Card
# 11492               3906770.0         Carrier Store          Gift Card
# 11493              65321410.0       Corporate / B2B        Credit Card
# 11494             118830880.0    Online (Apple.com)        Credit Card
# 11495              19575500.0  Third-Party Retailer          Gift Card
# 11496             166389790.0       Corporate / B2B          Gift Card
# 11497              86579325.0   Authorized Reseller         Debit Card
# 11498              10755255.0           Apple Store  EMI / Installment
# 11499              28972720.0    Online (Apple.com)  EMI / Installment
#
#       customer_segment customer_age_group previous_device_os  customer_rating  \
# 11490       Government              18–24                NaN              NaN
# 11491       Individual              18–24              Other              3.0
# 11492       Government              18–24                NaN              NaN
# 11493         Business                55+                NaN              3.6
# 11494         Business              18–24                NaN              NaN
# 11495       Individual              18–24                NaN              4.0
# 11496        Education              45–54                NaN              4.9
# 11497       Government              35–44             iOS 16              3.8
# 11498        Education                55+             iOS 17              NaN
# 11499       Individual              35–44              Other              3.6
#
#       return_status
# 11490          Kept
# 11491          Kept
# 11492          Kept
# 11493          Kept
# 11494          Kept
# 11495          Kept
# 11496          Kept
# 11497          Kept
# 11498          Kept
# 11499          Kept

# %%
rows, columns =  apple_df.shape
output = f"ROWS: {rows} || COLUMNS: {columns}"
print(output)
# Out:
# ROWS: 11500 || COLUMNS: 27

# %% [markdown]
# Insight:
# - Dataset has 11500 records and 27 features

# %% [markdown]
# #### Descriptive Stats
#
# - MCTs -> measures os central tendency (Mean, Median, Mode)
# - MoV -> measures of variation (range, IQR, percentile, quartiles,variance , standard deviation )

# %%
apple_df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 11500 entries, 0 to 11499
# Data columns (total 27 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   sale_id                 11500 non-null  str
#  1   sale_date               11500 non-null  str
#  2   year                    11500 non-null  int64
#  3   quarter                 11500 non-null  str
#  4   month                   11500 non-null  str
#  5   country                 11500 non-null  str
#  6   region                  11500 non-null  str
#  7   city                    11500 non-null  str
#  8   product_name            11500 non-null  str
#  9   category                11500 non-null  str
#  10  storage                 6696 non-null   str
#  11  color                   11500 non-null  str
#  12  unit_price_usd          11500 non-null  float64
#  13  discount_pct            11500 non-null  int64
#  14  units_sold              11500 non-null  int64
#  15  discounted_price_usd    11500 non-null  float64
#  16  revenue_usd             11500 non-null  float64
#  17  currency                11500 non-null  str
#  18  fx_rate_to_usd          11500 non-null  float64
#  19  revenue_local_currency  11500 non-null  float64
#  20  sales_channel           11500 non-null  str
#  21  payment_method          11500 non-null  str
#  22  customer_segment        11500 non-null  str
#  23  customer_age_group      11500 non-null  str
#  24  previous_device_os      3444 non-null   str
#  25  customer_rating         8140 non-null   float64
#  26  return_status           11500 non-null  str
# dtypes: float64(6), int64(3), str(18)
# memory usage: 2.4 MB

# %%
apple_df.dtypes
# Out:
# sale_id                       str
# sale_date                     str
# year                        int64
# quarter                       str
# month                         str
# country                       str
# region                        str
# city                          str
# product_name                  str
# category                      str
# storage                       str
# color                         str
# unit_price_usd            float64
# discount_pct                int64
# units_sold                  int64
# discounted_price_usd      float64
# revenue_usd               float64
# currency                      str
# fx_rate_to_usd            float64
# revenue_local_currency    float64
# sales_channel                 str
# payment_method                str
# customer_segment              str
# customer_age_group            str
# previous_device_os            str
# customer_rating           float64
# return_status                 str
# dtype: object

# %% [markdown]
# Insights:
# - A few columns in the dataset is composed of Null / empty values
# - composed of  both categorical and numerical data

# %%
apple_df.describe() # get desciptive stats of numerical data
# Out:
#                year  unit_price_usd  discount_pct    units_sold  \
# count  11500.000000    11500.000000  11500.000000  11500.000000
# mean    2022.997304      807.851191      3.841565      2.023478
# std        0.821747     1112.437595      4.783161      1.443599
# min     2022.000000       26.690000      0.000000      1.000000
# 25%     2022.000000      180.147500      0.000000      1.000000
# 50%     2023.000000      593.905000      2.000000      1.000000
# 75%     2024.000000      958.387500      7.000000      3.000000
# max     2024.000000     7551.010000     15.000000      8.000000
#
#        discounted_price_usd   revenue_usd  fx_rate_to_usd  \
# count          11500.000000  11500.000000    11500.000000
# mean             777.365478   1568.319065     1029.406647
# std             1072.915122   2839.759822     4072.334957
# min               22.730000     23.000000        0.790000
# 25%              178.297500    305.740000        0.920000
# 50%              573.420000    833.040000        7.240000
# 75%              928.567500   1748.360000       91.500000
# max             7551.010000  59529.520000    24500.000000
#
#        revenue_local_currency  customer_rating
# count            1.150000e+04      8140.000000
# mean             1.464369e+06         4.000934
# std              9.941160e+06         0.575192
# min              2.130000e+01         3.000000
# 25%              1.041693e+03         3.500000
# 50%              6.164160e+03         4.000000
# 75%              7.471653e+04         4.500000
# max              5.075175e+08         5.000000

# %% [markdown]
# Insights:
#
# 1. Year:
# - it between 2022 and 2024, with 75% of the sales made below 2024 and 50% pf the sales were around 2023

# %%
apple_df.describe(include='object') # get desciptive stats of numerical data
# Out:
# /tmp/ipykernel_11207/1766351801.py:1: Pandas4Warning: For backward compatibility, 'str' dtypes are included by select_dtypes when 'object' dtype is specified. This behavior is deprecated and will be removed in a future version. Explicitly pass 'str' to `include` to select them, or to `exclude` to remove them and silence this warning.
# See https://pandas.pydata.org/docs/user_guide/migration-3-strings.html#string-migration-select-dtypes for details on how to write code that works with pandas 2 and 3.
#   apple_df.describe(include='object') # get desciptive stats of numerical data
#               sale_id   sale_date quarter  month country  region       city  \
# count           11500       11500   11500  11500   11500   11500      11500
# unique          11500        1096       4     12      47       8        514
# top     APPL-00000001  2022-07-31      Q4  March   Japan  Europe  Singapore
# freq                1          23    2922   1047     274    3898        237
#
#                     product_name category storage   color currency  \
# count                      11500    11500    6696   11500    11500
# unique                        43        6      10      20       38
# top     Apple Watch SE (2nd Gen)   iPhone   64 GB  Silver      EUR
# freq                         312     3444     944    1690     2433
#
#              sales_channel payment_method customer_segment customer_age_group  \
# count                11500          11500            11500              11500
# unique                   6              7                4                  5
# top     Online (Apple.com)    Credit Card       Government              25–34
# freq                  1940           1683             2892               2347
#
#        previous_device_os return_status
# count                3444         11500
# unique                  6             3
# top               Android          Kept
# freq                  595         10143

# %% [markdown]
# Insights:
# -
