# %% [markdown]
# # **Business Understanding**
# The data is related with direct marketing campaigns of a Portuguese banking institution. The marketing campaigns were based on phone calls. Often, more than one contact to the same client was required, in order to access if the product (bank term deposit) would be ('yes') or not ('no') subscribed.
#
#
# Moro, S., Rita, P., & Cortez, P. (2014). Bank Marketing [Dataset]. UCI Machine Learning Repository. https://doi.org/10.24432/C5K306.
#
# [SOURCE](https://www.kaggle.com/datasets/nimishsawant/bankfull)
# [DATA SOURCE](https://archive.ics.uci.edu/dataset/222/bank+marketing)

# %% [markdown]
# ### **Load libraries**

# %%
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt

# %% [markdown]
# ### **Load Data**

# %%
bank_df = pd.read_csv("data/bank-full.csv")

# %% [markdown]
# # **Data Understanding**
# - head and tail (printing out the first 5 or few entries and the last entries)
# - shape (dimensions)
# - columns
# - datatypes
# - info
# - duplicates
# - null value check
# - describe numerical (descriptive)
# - describe categroical

# %% [markdown]
# ### **Glimpse of the data**

# %%
bank_df.head()
# Out:
#    age           job  marital  education default  balance housing loan  \
# 0   58    management  married   tertiary      no     2143     yes   no
# 1   44    technician   single  secondary      no       29     yes   no
# 2   33  entrepreneur  married  secondary      no        2     yes  yes
# 3   47   blue-collar  married    unknown      no     1506     yes   no
# 4   33       unknown   single    unknown      no        1      no   no
#
#    contact  day month  duration  campaign  pdays  previous poutcome Target
# 0  unknown    5   may       261         1     -1         0  unknown     no
# 1  unknown    5   may       151         1     -1         0  unknown     no
# 2  unknown    5   may        76         1     -1         0  unknown     no
# 3  unknown    5   may        92         1     -1         0  unknown     no
# 4  unknown    5   may       198         1     -1         0  unknown     no

# %%
bank_df.tail()
# Out:
#        age           job   marital  education default  balance housing loan  \
# 45206   51    technician   married   tertiary      no      825      no   no
# 45207   71       retired  divorced    primary      no     1729      no   no
# 45208   72       retired   married  secondary      no     5715      no   no
# 45209   57   blue-collar   married  secondary      no      668      no   no
# 45210   37  entrepreneur   married  secondary      no     2971      no   no
#
#          contact  day month  duration  campaign  pdays  previous poutcome  \
# 45206   cellular   17   nov       977         3     -1         0  unknown
# 45207   cellular   17   nov       456         2     -1         0  unknown
# 45208   cellular   17   nov      1127         5    184         3  success
# 45209  telephone   17   nov       508         4     -1         0  unknown
# 45210   cellular   17   nov       361         2    188        11    other
#
#       Target
# 45206    yes
# 45207    yes
# 45208    yes
# ...

# %%
records, features = bank_df.shape
output = f"The data set has {records} records and {features} features"
print(output)
# Out:
# The data set has 45211 records and 17 features

# %%
bank_df.columns
# Out:
# Index(['age', 'job', 'marital', 'education', 'default', 'balance', 'housing',
#        'loan', 'contact', 'day', 'month', 'duration', 'campaign', 'pdays',
#        'previous', 'poutcome', 'Target'],
#       dtype='str')

# %% [markdown]
# ### **Info and Datatypes**

# %%
bank_df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 45211 entries, 0 to 45210
# Data columns (total 17 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   age        45211 non-null  int64
#  1   job        45211 non-null  str
#  2   marital    45211 non-null  str
#  3   education  45211 non-null  str
#  4   default    45211 non-null  str
#  5   balance    45211 non-null  int64
#  6   housing    45211 non-null  str
#  7   loan       45211 non-null  str
#  8   contact    45211 non-null  str
#  9   day        45211 non-null  int64
#  10  month      45211 non-null  str
#  11  duration   45211 non-null  int64
#  12  campaign   45211 non-null  int64
#  13  pdays      45211 non-null  int64
#  14  previous   45211 non-null  int64
#  15  poutcome   45211 non-null  str
#  16  Target     45211 non-null  str
# dtypes: int64(7), str(10)
# memory usage: 5.9 MB

# %%
bank_df.dtypes
# Out:
# age          int64
# job            str
# marital        str
# education      str
# default        str
# balance      int64
# housing        str
# loan           str
# contact        str
# day          int64
# month          str
# duration     int64
# campaign     int64
# pdays        int64
# previous     int64
# poutcome       str
# Target         str
# dtype: object

# %% [markdown]
# ### **Missing Values & Duplicates**

# %%
bank_df.isna().sum()
# Out:
# age          0
# job          0
# marital      0
# education    0
# default      0
# balance      0
# housing      0
# loan         0
# contact      0
# day          0
# month        0
# duration     0
# campaign     0
# pdays        0
# previous     0
# poutcome     0
# Target       0
# dtype: int64

# %%
bank_df.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# ### **Descriptive Stats**
# - Numerical
# - Categorical

# %%
bank_df.describe()
# Out:
#                 age        balance           day      duration      campaign  \
# count  45211.000000   45211.000000  45211.000000  45211.000000  45211.000000
# mean      40.936210    1362.272058     15.806419    258.163080      2.763841
# std       10.618762    3044.765829      8.322476    257.527812      3.098021
# min       18.000000   -8019.000000      1.000000      0.000000      1.000000
# 25%       33.000000      72.000000      8.000000    103.000000      1.000000
# 50%       39.000000     448.000000     16.000000    180.000000      2.000000
# 75%       48.000000    1428.000000     21.000000    319.000000      3.000000
# max       95.000000  102127.000000     31.000000   4918.000000     63.000000
#
#               pdays      previous
# count  45211.000000  45211.000000
# mean      40.197828      0.580323
# std      100.128746      2.303441
# min       -1.000000      0.000000
# 25%       -1.000000      0.000000
# 50%       -1.000000      0.000000
# ...

# %%
highst_contacted_client = bank_df.loc[bank_df['pdays'] == 871]
highst_contacted_client
# Out:
#        age         job   marital education default  balance housing loan  \
# 45146   49  unemployed  divorced  tertiary      no      780      no   no
#
#         contact  day month  duration  campaign  pdays  previous poutcome  \
# 45146  cellular    8   nov       148         1    871         2  failure
#
#       Target
# 45146     no

# %%
bank_df.describe(include='object')
# Out:
# /tmp/ipykernel_7559/3010343606.py:1: Pandas4Warning: For backward compatibility, 'str' dtypes are included by select_dtypes when 'object' dtype is specified. This behavior is deprecated and will be removed in a future version. Explicitly pass 'str' to `include` to select them, or to `exclude` to remove them and silence this warning.
# See https://pandas.pydata.org/docs/user_guide/migration-3-strings.html#string-migration-select-dtypes for details on how to write code that works with pandas 2 and 3.
#   bank_df.describe(include='object')
#                 job  marital  education default housing   loan   contact  \
# count         45211    45211      45211   45211   45211  45211     45211
# unique           12        3          4       2       2      2         3
# top     blue-collar  married  secondary      no     yes     no  cellular
# freq           9732    27214      23202   44396   25130  37967     29285
#
#         month poutcome Target
# count   45211    45211  45211
# ...

# %% [markdown]
# #### Insights:
#
# - The data set has **45211** records and **17** features
# - We have 7 quantittative data types and 10 qualitative data types
# - memory usage is at 5.9 MB
# - in terms of data integrity we have 0 duplicates and 0 missing values
#
# ##### Numerical Data:
# **Age:**
# - Youngest person is 18 yrs old and oldest individual is 95 yrs old.
# - 25% of the group fall below 33 years old
# - 50% of the individuals at at 39 yrs old
# - 75% of th eindividuals fall below 48 yrs old
# - There is apossibility of an outlier i.e age 95 yrs old
# - most of the individuals fall aorund 40 yrs old.
# - the standard deviation is about 10 implying that the spreads by 10 => there s apossible outlier
#
# **Balance**
# - The average cash balance during the period of May 2008 to November 2010, was at 1362.272 Eurost
# - The spread of the data is higher than the mean, that is 3044.765829, this implies the existence of outliers
# - The highest debt is at 8019 Euros
# - The highest balance is at 102127 Euros
# - 25% of the balances fall below 72 Euros
# - 50% of the balances fall around 448 Euros
# - 75% of the balances fall below 1428 EUROS
#
# **Day**
#
# descr: Last contact day month
# def: BP = bank products
#
# - Majority days during the month fell around the 16th day of the month
# - standard deviation or rather the spread from the mean(MCT) is quite high hence there existence of an outlier here the outlir could be negligible due to the number of days in a month
# - Ealierst day is 1 and latest day is 31 of the months
# - 25% of the marketing of bank products were below the 8th day
# - 50% of marketing of BP were around day 16 of the month
# - 75% of the marketing of BP fell below 21st day of the month
# - IQR states that 'heavy' marketing falls between day 8 and and day 21

# %% [markdown]
# #### **Basic Visualizations**

# %%
# pie chart
def plotPieChart(labels, data):
    fig, ax = plt.subplots()
    ax.pie(sizes, labels=labels)

# %%
bank_poutcome_labels  = bank_df['poutcome'].unique()
bank_poutcome_labels
# Out:
# <StringArray>
# ['unknown', 'failure', 'other', 'success']
# Length: 4, dtype: str

# %%
bank_df['poutcome'].value_counts()
# Out:
# poutcome
# unknown    36959
# failure     4901
# other       1840
# success     1511
# Name: count, dtype: int64

# %%
data = list(bank_df['poutcome'].value_counts())
data
# Out:
# [36959, 4901, 1840, 1511]

# %%
plotPieChart(bank_poutcome_labels,data)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 plotPieChart(bank_poutcome_labels,data)
#
# Cell In[14], line 4, in plotPieChart(labels, data)
#       2 def plotPieChart(labels, data):
#       3     fig, ax = plt.subplots()
# ----> 4     ax.pie(sizes, labels=labels)
#
# NameError: name 'sizes' is not defined

# %%
marital_labels  = bank_df['marital'].unique()
marital_labels
# Out:
# <StringArray>
# ['married', 'single', 'divorced']
# Length: 3, dtype: str

# %%
marital_data = list(bank_df['marital'].value_counts()) 
marital_data[0]
# Out:
# 27214

# %%
# TODO: DEBUG
# ERROR 
plotPieChart(marital_labels, marital_data)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[55], line 1
# ----> 1 plotPieChart(marital_labels, marital_data)
#
# Cell In[26], line 4, in plotPieChart(labels, data)
#       2 def plotPieChart(labels, data):
#       3     fig, ax = plt.subplots()
# ----> 4     ax.pie(sizes, labels=labels)
#
# File ~/Desktop/DSA_case_study_1/env/lib/python3.11/site-packages/matplotlib/_api/deprecation.py:453, in make_keyword_only.<locals>.wrapper(*args, **kwargs)
#     447 if len(args) > name_idx:
#     448     warn_deprecated(
#     449         since, message="Passing the %(name)s %(obj_type)s "
#     450         "positionally is deprecated since Matplotlib %(since)s; the "
#     451         "parameter will become keyword-only in %(removal)s.",
#     452         name=name, obj_type=f"parameter of {func.__name__}()")
# --> 453 return func(*args, **kwargs)
#
# ...

# %% [markdown]
# ##### Insights:
# - Majority of the (outcome of the previous marketing campaign (categorical: "unknown","other","failure","success")) fell on others (not well defined)
# - The team had few success rates and slightly higher failure rates

# %%
jobs  = bank_df['job'].unique()
jobs
# Out:
# <StringArray>
# [   'management',    'technician',  'entrepreneur',   'blue-collar',
#        'unknown',       'retired',        'admin.',      'services',
#  'self-employed',    'unemployed',     'housemaid',       'student']
# Length: 12, dtype: str

# %%
jobs_freq = bank_df['job'].value_counts()
jobs_freq
# Out:
# job
# blue-collar      9732
# management       9458
# technician       7597
# admin.           5171
# services         4154
# retired          2264
# self-employed    1579
# entrepreneur     1487
# unemployed       1303
# housemaid        1240
# student           938
# unknown           288
# Name: count, dtype: int64

# %%
jobs = dict(jobs_freq)
jobs['retired']
# Out:
# np.int64(2264)

# %%
bank_df['duration'].plot(kind='bar')
# Out:
# <Axes: >
# Error in callback <function flush_figures at 0x7fa7b1850900> (for post_execute), with arguments args (),kwargs {}:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# File ~/Desktop/DSA_case_study_1/env/lib/python3.11/site-packages/matplotlib_inline/backend_inline.py:126, in flush_figures()
#     123 if InlineBackend.instance().close_figures:
#     124     # ignore the tracking, just draw and close all figures
#     125     try:
# --> 126         return show(True)
#     127     except Exception as e:
#     128         # safely show traceback if in IPython, else raise
#     129         ip = get_ipython()
#
# File ~/Desktop/DSA_case_study_1/env/lib/python3.11/site-packages/matplotlib_inline/backend_inline.py:90, in show(close, block)
#      88 try:
#      89     for figure_manager in Gcf.get_all_fig_managers():
# ---> 90         display(
# ...

# %%
bank_df['job'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='job'>

# %%
fig, ax = plt.subplots()

fruits = ['apple', 'blueberry', 'cherry', 'orange'] # unique labels
counts = [40, 100, 30, 55] # frequency
bar_labels = ['red', 'blue', '_red', 'orange']
bar_colors = ['tab:red', 'tab:blue', 'tab:red', 'tab:orange']

ax.bar(fruits, counts, label=bar_labels, color=bar_colors)

ax.set_ylabel('fruit supply')
ax.set_title('Fruit supply by kind and color')
ax.legend(title='Fruit color')

plt.show()

# %%
bank_df.head()
# Out:
#    age           job  marital  education default  balance housing loan  \
# 0   58    management  married   tertiary      no     2143     yes   no
# 1   44    technician   single  secondary      no       29     yes   no
# 2   33  entrepreneur  married  secondary      no        2     yes  yes
# 3   47   blue-collar  married    unknown      no     1506     yes   no
# 4   33       unknown   single    unknown      no        1      no   no
#
#    contact  day month  duration  campaign  pdays  previous poutcome Target
# 0  unknown    5   may       261         1     -1         0  unknown     no
# 1  unknown    5   may       151         1     -1         0  unknown     no
# 2  unknown    5   may        76         1     -1         0  unknown     no
# 3  unknown    5   may        92         1     -1         0  unknown     no
# 4  unknown    5   may       198         1     -1         0  unknown     no

# %%
bank_df.groupby('poutcome')['duration'].mean()
# Out:
# poutcome
# failure    244.185880
# other      255.715217
# success    316.868961
# unknown    257.738332
# Name: duration, dtype: float64

# %%
bank_df.groupby('poutcome')['campaign'].mean()
# Out:
# poutcome
# failure    1.980820
# other      2.461413
# success    1.806089
# unknown    2.921886
# Name: campaign, dtype: float64

# %%
pd.crosstab(pd.qcut(bank_df['duration'],4), bank_df['poutcome'], normalize='index')
# Out:
# poutcome          failure     other   success   unknown
# duration
# (-0.001, 103.0]  0.103912  0.042549  0.012396  0.841143
# (103.0, 180.0]   0.116881  0.038192  0.026407  0.818520
# (180.0, 319.0]   0.114880  0.039504  0.048804  0.796811
# (319.0, 4918.0]  0.097949  0.042536  0.046266  0.813249

# %%
number = np.random.randint(1,7,1)
number
# Out:
# array([4])
